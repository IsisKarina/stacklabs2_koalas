# %% [markdown]
# <a href="https://colab.research.google.com/github/IsisKarina/stacklabs2_koalas/blob/main/engenharia_de_dados_stacklabs2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Projeto Engenharia de Dados - Previsão de Vendas Cruzadas - Stack Labs 2**

# %% [markdown]
# ##**Overview**

# %% [markdown]
# Este projeto de engengaria de dados foi desenvolvido todo na AWS, pois de comum acordo com a equipe, gostariamos que fosse o mais próximo da vida real possivel.

# %% [markdown]
# ![unknown.png](data:image/png;base64,...)

# %% [markdown]
# Foram construídos três buckets para a transição dos dados na AWS S3 para a transição dos dados, como:
#
# - Landing Zone
# - Processing Zone
# - Curated Zone

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### **Landing** **Zone**

# %% [markdown]
# É a zona de recebimento dos dados brutos.
#
# Nesta etapa os dados ainda não receberam nenhum tipo de tratamento.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### **Processing Zone**

# %% [markdown]
# Nesta zona os dados recebem algum tipo de tratamento, como identificação de missing values.
#
# Nesta etapa no nosso projeto decidimos já habilitar uma máquina EC2, pois conforme definição da equipe usamos também o Sagemaker.
#
# Diante disso nessa etapa também fizemos todo o EDA do projeto e o Machine Learning.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ####**Curated Zone**

# %% [markdown]
# Nesta fase do projeto decidimos então pelo deploy do projeto.
#
# Novamente ele foi desenvolvido dentro do Sagemaker que é uma ferramenta robusta para Machine Learning.

# %% [markdown]
# ![Capturar3.PNG](data:image/png;base64,...)
